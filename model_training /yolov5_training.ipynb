# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # DATA

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CefEHPDaGuCC15RLKBRq")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 3265.84it/s]

# %%
dataset.location
# Out:
# '/teamspace/studios/this_studio/football-players-detection-1'

# %% [markdown]
# # Train

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
# Define paths
data_yaml_path = '/teamspace/studios/this_studio/football-players-detection-1/data.yaml'
model_weights_path = '/teamspace/studios/this_studio/yolov5xu.pt'

# Run YOLOv5 training
# !yolo task=detect mode=train model=yolov5x.pt data={data_yaml_path} epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.60 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
